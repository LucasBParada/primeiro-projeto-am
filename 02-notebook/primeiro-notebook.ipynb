# %% [markdown]
# Primeiro Notebook AM

# %%
print("Teste")
# Out:
# Teste

# %% [markdown]
# Estrutura de dados nativas

# %%
dados_entrada = [10,20,30,40,50]
print(f"Lista de Entradas: {dados_entrada}")
# Out:
# Lista de Entradas: [10, 20, 30, 40, 50]
